# %% [markdown]
# # TSNE with new model

# %% [markdown]
# ## Model Setup (from model.ipynb)

# %% [markdown]
# ### Load Packages

# %%
# Main modules 
import torch
from torch import Generator
from torch.utils.data import DataLoader, random_split
import torchvision
from torchvision.datasets import ImageFolder
from torchvision.transforms.functional import to_pil_image
import pandas as pd
import matplotlib.pyplot as plt

# Custom modules
from frogfunctions import Model 
from frogfunctions import setup_seed, train_loop, test_loop, train_model, plot_probabilities

# %%
# Dataframe output format
pd.set_option('display.float_format', lambda x: '%.6f' % x)

# Set device 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# ### Set random seed for reproduction

# %%
SEED = 42
setup_seed(SEED)

# %% [markdown]
# ### Import data

# %%
data_dir = "../data/"

# %%
# Download and load the training data
dataset_all = ImageFolder(data_dir, transform=torchvision.transforms.ToTensor())

# Print number in full data set
size_all = len(dataset_all)
print(f'Before splitting the full dataset into train and test: len(dataset_all) = {size_all}')

# Split into Test, Validation, and Training
size_test = int(size_all * 0.10)
size_val = int(size_all * 0.10)
size_train = size_all - size_test - size_val
dataset_test, dataset_val, dataset_train = random_split(dataset_all, [size_test, size_val, size_train], 
                                                        generator=Generator().manual_seed(SEED))

print(f'After splitting the full dataset into test, validation, and training: \n \
      len(dataset_test) = {len(dataset_test)} \n \
      len(dataset_val) = {len(dataset_val)} \n \
      len(dataset_train) = {len(dataset_train)}')
# Out:
# Before splitting the full dataset into train and test: len(dataset_all) = 700
# After splitting the full dataset into test, validation, and training:
#        len(dataset_test) = 70
#        len(dataset_val) = 70
#        len(dataset_train) = 560

# %% [markdown]
# ### Prepare data

# %%
# Define batch size
batch_size = 16

# %%
# Load data into DataLoader
train_dataloader = DataLoader(dataset_train, batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(dataset_val, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(dataset_test, batch_size=batch_size, shuffle=True)

dataloaders = {'train':train_dataloader, 'val':val_dataloader}
dataset_sizes = {'train':len(dataset_train), 'val':len(dataset_val)}

# %% [markdown]
# ### Define parameters for model

# %%
# Define number of classes
num_classes = 7

# %%
# Create model 
model = Model(num_classes=num_classes).to(device)

# %%
# Define hyperparameters
learning_rate = 0.002
weight_decay = 0.005
momentum=0.09

# Define loss function
loss_fn = torch.nn.CrossEntropyLoss()

# Define optimizer 
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, weight_decay=weight_decay, momentum=momentum)

# %% [markdown]
# ### Train model

# %%
# Set number of epochs 
epochs = 20

# Train
train_model(train_dataloader, val_dataloader, model, loss_fn, optimizer, epochs, tsne=True)
# Out:
# Epoch 1
# -------------------------------
# loss: 1.936880  [   16/  560]
# Training Error: Accuracy: 25.7%
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# Validation Error: Accuracy: 8.6%, Avg loss: 1.935219
#
# Epoch 2
# -------------------------------
# loss: 1.913679  [   16/  560]
# Training Error: Accuracy: 39.8%
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# Validation Error: Accuracy: 52.9%, Avg loss: 1.830262
#
# Epoch 3
# -------------------------------
# loss: 1.878431  [   16/  560]
# Training Error: Accuracy: 50.0%
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# Validation Error: Accuracy: 70.0%, Avg loss: 1.719358
#
# Epoch 4
# -------------------------------
# loss: 1.754495  [   16/  560]
# Training Error: Accuracy: 66.6%
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# Validation Error: Accuracy: 65.7%, Avg loss: 1.614157
#
# Epoch 5
# -------------------------------
# loss: 1.657056  [   16/  560]
# Training Error: Accuracy: 65.0%
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# Validation Error: Accuracy: 77.1%, Avg loss: 1.394160
#
# Epoch 6
# -------------------------------
# loss: 1.425105  [   16/  560]
# Training Error: Accuracy: 75.0%
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# Validation Error: Accuracy: 75.7%, Avg loss: 1.217220
#
# Epoch 7
# -------------------------------
# loss: 1.190531  [   16/  560]
# Training Error: Accuracy: 82.3%
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# Validation Error: Accuracy: 90.0%, Avg loss: 1.014249
#
# Epoch 8
# -------------------------------
# loss: 1.117722  [   16/  560]
# Training Error: Accuracy: 86.1%
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# Validation Error: Accuracy: 87.1%, Avg loss: 0.739192
#
# Epoch 9
# -------------------------------
# loss: 0.725641  [   16/  560]
# Training Error: Accuracy: 89.3%
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# Validation Error: Accuracy: 90.0%, Avg loss: 0.584053
#
# Epoch 10
# -------------------------------
# loss: 0.628633  [   16/  560]
# Training Error: Accuracy: 91.6%
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# Validation Error: Accuracy: 94.3%, Avg loss: 0.398872
#
# Epoch 11
# -------------------------------
# loss: 0.445046  [   16/  560]
# Training Error: Accuracy: 92.5%
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# Validation Error: Accuracy: 94.3%, Avg loss: 0.339142
#
# Epoch 12
# -------------------------------
# loss: 0.246471  [   16/  560]
# Training Error: Accuracy: 93.0%
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# Validation Error: Accuracy: 95.7%, Avg loss: 0.322703
#
# Epoch 13
# -------------------------------
# loss: 0.237566  [   16/  560]
# Training Error: Accuracy: 94.6%
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# Validation Error: Accuracy: 95.7%, Avg loss: 0.269431
#
# Epoch 14
# -------------------------------
# loss: 0.256614  [   16/  560]
# Training Error: Accuracy: 95.0%
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# Validation Error: Accuracy: 95.7%, Avg loss: 0.205224
#
# Epoch 15
# -------------------------------
# loss: 0.225741  [   16/  560]
# Training Error: Accuracy: 97.0%
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# Validation Error: Accuracy: 95.7%, Avg loss: 0.145286
#
# Epoch 16
# -------------------------------
# loss: 0.211740  [   16/  560]
# Training Error: Accuracy: 96.6%
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# Validation Error: Accuracy: 97.1%, Avg loss: 0.147352
#
# Epoch 17
# -------------------------------
# loss: 0.222188  [   16/  560]
# Training Error: Accuracy: 96.6%
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# Validation Error: Accuracy: 98.6%, Avg loss: 0.115849
#
# Epoch 18
# -------------------------------
# loss: 0.237948  [   16/  560]
# Training Error: Accuracy: 98.0%
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# Validation Error: Accuracy: 97.1%, Avg loss: 0.104787
#
# Epoch 19
# -------------------------------
# loss: 0.231188  [   16/  560]
# Training Error: Accuracy: 97.3%
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# Validation Error: Accuracy: 97.1%, Avg loss: 0.092406
#
# Epoch 20
# -------------------------------
# loss: 0.174823  [   16/  560]
# Training Error: Accuracy: 98.0%
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# Validation Error: Accuracy: 97.1%, Avg loss: 0.076354
#
# Processing time: 173.55s.
